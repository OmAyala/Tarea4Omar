# %% [markdown]
# # Tarea 4
#
# ## Omar Ayala

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pyreadstat
# Leer el archivo .sav
archivo_sav = 'Casen_2017.sav'
datos, metadatos = pyreadstat.read_sav(archivo_sav)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216439 entries, 0 to 216438
# Columns: 804 entries, folio to pobreza_multi_5d
# dtypes: float64(768), object(36)
# memory usage: 1.3+ GB

# %% [markdown]
# # Variables a usar
#
# ### Cualitativas
# **e1**:  Nominal. Indica si la persona sabe leer y/o escribir. <br>
# Toma los valores: <br>
# 1 Lee y escribe<br>
# 2 Solo lee<br>
# 3 Solo escribe<br>
# 4 Ninguno<br>
# 9 No sabe/responde<br>
#
# **region**:  Nominal. Indica la region.<br>
# Toma los valores:<br>
# 1 Región de Tarapacá<br>
# 2 Región de Antofagasta<br>
# 3 Región de Atacama<br>
# 4 Región de Coquimbo<br>
# 5 Región de Valparaíso<br>
# 6 Región del Libertador Gral. Bernardo O'Higgins<br>
# 7 Región del Maule<br>
# 8 Región del Biobío<br>
# 9 Región de La Araucanía<br>
# 10 Región de Los Lagos<br>
# 11 Región de Aysén del Gral. Carlos Ibáñez del Campo<br>
# 12 Región de Magallanes y de la Antártica Chilena<br>
# 13 Región Metropolitana de Santiago<br>
# 14 Región de Los Ríos<br>
# 15 Región de Arica y Parinacota<br>
# 16 Región de Ñuble<br>
#
# **e6a**:  Nominal. Indica el nivel educacional más alto alcanzado o el nivel educacional actual. Esta variable a simple vista es Ordinal, pero luego de analizar los posibles valores, no puedo decir que la edicación Primaria del Sistema antiguo es un nivel más bajo que la Educación Básica actual, o que la Educación Media Técnia Profesional es mayor que la Científico-Humanista.<br>
# Toma los valores:<br>
# 1 Nunca asistió<br>
# 2 Sala cuna<br>
# 3 Jardín Infantil<br>
# 4 Prekinder/Kinder<br>
# 5 Educación Diferencial<br>
# 6 Primaria(Sistema antiguo)<br>
# 7 Educación Básica<br>
# 8 Humanidades (Sistema antiguo)<br>
# 9 Educación Media Científico-Humanista<br>
# 10 Técnica, Comercial, Industrial o Normalista(Sistema Antiguo)<br>
# 11 Educación Media Técnica Profesional<br>
# 12 Técnico Nivel Superior Incompleto<br>
# 13 Técnico Nivel Superior Completo<br>
# 14 Profesional Incompleto<br>
# 15 Profesional Completo<br>
# 16 Postgrado Incompleto<br>
# 17 Postgrado Completo<br>
# 99 No sabe/responde<br>
#
# **s12**:  Nominal. Indica la previsión de salud.<br>
# Toma los valores:<br>
# 1 Sistema Público FONASA Grupo A<br>
# 2 Sistema Público FONASA Grupo B<br>
# 3 Sistema Público FONASA Grupo C<br>
# 4 Sistema Público FONASA Grupo D<br>
# 5 Sistema Público FONASA Grupo No sabe grupo<br>
# 6 FF.AA. y de Orden<br>
# 7 ISAPRE<br>
# 8 Ninguno(Particular)<br>
# 9 Otro sistema<br>
# 99 No sabe/responde<br>
#
#
#
# ### Cuantitativas
#
# **edad**: Continua. Indica la edad de la persona. Toma valores positivos. <br>
# **o10**: Continua. Indica las horas semanales trabajadas. Toma valores positivos. <br>
# **y1**: Continua. Indica el salario mensual. Toma valores positivos.<br>
# **v27a**: Discreta. Indica la cantidad de dormitorios en la casa. Toma valores positivos. <br>

# %% [markdown]
# ## Preguntas a responder y variables relacionadas a cada pregunta
#
# 1. ¿En qué región hay más gente que sabe leer y escribir? Usamos las variables **e1** y **region** *Cuali y Cuali*
# 2. ¿Qué nivel de enseñanza tiene la mediana de la población? **e6a**
# 3. ¿Salario maximo registrado? **y1**
# 4. ¿La gente que trabaja más horas a la semana tiene un mayor nivel de educación? **o10** y **e6a** *Cuanti y Cuali*
# 5. ¿En qué sistema previsional de salud hay más gente que no sabe leer ni escribir? **e1** y  **s12** *Cuali y Cuali*
# 6. ¿La vivienda tiene más dormitorios si tengo mayor nivel educacional? **v27a** y **e64** *Cuanti y Cuali*
# 7. ¿Que región tiene mayor Q3 de edad? **region** y **edad** *Cuanti y Cuali*
# 8. ¿Porcentaje de personas con Fonasa A? **s12**
# 9. ¿Cuántas horas trabaja el promedio de la gente? **o10**
# 10. ¿Cuál es la previsión más común en La Araucanía? **region** y **s12** *Cuali y Cuali*

# %% [markdown]
# ## Medidas descriptivas por variable e interpretación.

# %%
datos.region.describe().loc[['mean', 'std','min','25%','50%','75%','max']]
# Out:
# mean     8.812002
# std      4.201065
# min      1.000000
# 25%      5.000000
# 50%      9.000000
# 75%     13.000000
# max     16.000000
# Name: region, dtype: float64

# %% [markdown]
# No tiene lógica interpretar estos datos.

# %%
datos.e1.describe().loc[['mean', 'std','min','25%','50%','75%','max']]
# Out:
# mean    1.117440
# std     0.591338
# min     1.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     9.000000
# Name: e1, dtype: float64

# %% [markdown]
# Podríamos decir que la mayoría de la población sabe leer y escribir ya que el promedio es muy cercano a 1, y el 75% también es 1, con una desviación estandar pequeña, lo que indica muchas datos cercanos al promedio.

# %%
datos.e6a.describe().loc[['mean', 'std','min','25%','50%','75%','max']]
# Out:
# mean     9.121923
# std      5.804464
# min      1.000000
# 25%      7.000000
# 50%      9.000000
# 75%     11.000000
# max     99.000000
# Name: e6a, dtype: float64

# %% [markdown]
# En promedio la gente tiene Educación Media Científico Humanista.
# Las otras medidas no tienen mucha lógica.

# %% [markdown]
# Con esto respondemos la pregunta 2: <br>
#
# 2-¿Qué nivel de enseñanza tiene la mediana de la población? <br>
#
# Educación Media Científico-Humanista

# %%
datos.s12.describe().loc[['mean', 'std','min','25%','50%','75%','max']]
# Out:
# mean     5.449716
# std     14.829401
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      5.000000
# max     99.000000
# Name: s12, dtype: float64

# %% [markdown]
# No tiene lógica interpretar estos datos.

# %%
datos.edad.describe().loc[['mean', 'std','min','25%','50%','75%','max']]
# Out:
# mean     37.780257
# std      22.950752
# min       0.000000
# 25%      19.000000
# 50%      36.000000
# 75%      56.000000
# max     117.000000
# Name: edad, dtype: float64

# %% [markdown]
# EN promedio, la gente tiene 38 años, aunque la desviación estandar es alta.
# El 25% de la gente tiene 19 años o menos, el 50% de la población tiene 36 años, y el 75% tiene 56 o menos años.
# Hay una persona con 117 años wow.

# %%
datos.o10.describe().loc[['mean', 'std','min','25%','50%','75%','max']]
# Out:
# mean     42.900602
# std      14.818827
# min       1.000000
# 25%      40.000000
# 50%      45.000000
# 75%      45.000000
# max     220.000000
# Name: o10, dtype: float64

# %% [markdown]
# En promedio la gente trabaja 42 horas semanales, con un desviación alta.
# El 25% de la gente trabaja 40 o menos horas a la semana, y el 50% y 75% comparten trabajar 45 horas semanales o menos, mucha gente trabaj en este rango.
# Una persona se inventa tiempo para trabajar 220 horas semanales ya que una semana tiene 168 horas.

# %% [markdown]
# Repondemos pregunta 9:<br>
#
# 9. ¿Cuantas horas trabaja el promedio de la gente? <br>
#
# El promedio trabaja 42 horas.

# %%
datos.y1.describe().loc[['mean', 'std','min','25%','50%','75%','max']]
# Out:
# mean    4.684790e+05
# std     5.787864e+05
# min     0.000000e+00
# 25%     2.600000e+05
# 50%     3.100000e+05
# 75%     5.000000e+05
# max     3.400000e+07
# Name: y1, dtype: float64

# %% [markdown]
# El promedio la gente gana 468000 pesos al mes, con una desvianción estandar enorme indicando mucha diferencia.
# El 25% de la problación vive con 260000 pesos o menos al mes, el 50% con 310000, y el 75% con 500000.

# %% [markdown]
# Con esto respondemos la pregunta 3: <br>
#
# 3.¿Salario maximo registrado? <br>
#
# 34000000

# %%
datos.v27a.describe().loc[['mean', 'std','min','25%','50%','75%','max']]
# Out:
# mean     3.174677
# std      3.469592
# min      0.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max     99.000000
# Name: v27a, dtype: float64

# %% [markdown]
# En promedio la gente tiene 3 dormitorios en su casa.
# El 25%, 50% y 75% de la gente tiene 2, 3 y 4 dormitorios o menos en su casa.
# El 99 es alguien que no sabía cuantos dormmitorios tenía su casa, debí limpiar los datos.

# %%
plt.figure(figsize=(20,20))
count_plot = sns.countplot(x = datos.region, hue = datos.e1)
plt.title('Gráfico de barras para la variable Saber leer por Comuna',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('region')
plt.show()

# %% [markdown]
# La gran mayoría de la población en todas las regiones saber leer y escribir.
# En las regiones con más gente que no sabe leer ni escribir están la Región del Biobío, La Araucanía, Del Maule, De O'Higgins y la Metropolitana.

# %% [markdown]
# Con esto respondemos la pregunta 1: <br>
#
# 1-¿En qué región hay más gente que sabe leer y escribir? <br>
#
# En la Región Metropolitana

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x=datos['e6a'],y=datos['o10']) #x debe ser categórica e y continua
plt.title('Diagrama de caja de la variable NIvel Educacional por Horas semanales trabajadas',y=1.01)
plt.xlabel('Nivel Educacional')
plt.ylabel('Horas semanales trabajadas')
plt.show()

# %% [markdown]
# La gente trabaja casi lo mismo a través de su nivel educacional. La gente con educación Media C-H, Media T-P, y Técnica Superior tiene unas cajitas aplastadas, lo que indica que mucha gente en estos niveles trabaja casi la misma cantidad de horas semanales.

# %% [markdown]
# Con esto respondemos la pregunta 4: <br>
#
# 4.¿La gente que trabaja más horas a la semana tiene un mayor nivel de educación? <br>
# En promedio todos trabajan lo mismo excepto la gente que solo fue a sala cuna que tiene un 75% de la gente trabajando más.

# %%
plt.figure(figsize=(20,20))
count_plot = sns.countplot(x = datos.s12, hue = datos.e1)
plt.title('Gráfico de barras para la variable Previsión de Salud por Saber leer',y=1.01)
plt.xlabel('Previsión de salud')
plt.ylabel('Conteo')
plt.show()

# %% [markdown]
# Fonasa A y B tiene la mayoría de la gente que no sabe leer o escribir.
# Fonasa A y B son las más populares.

# %% [markdown]
# Respondemos a la pregunta 5 <br>
#
# ¿En qué sistema previsional de salud hay más gente que no sabe leer ni escribir?<br>
#
# En Fonasa B, por poco le sigue la Fonasa A.

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x=datos['e6a'],y=datos['v27a']) #x debe ser categórica e y continua
plt.title('Diagrama de caja de la variable dormitorios por nivel educ',y=1.01)
plt.xlabel('Nivel Educacional')
plt.ylabel('Dormitorios')
plt.show()

# %% [markdown]
# En general, la gente tiende a tener casas con la misma cantidad de dormitorios.
# Hay outliers en todos los niveles ocn valores parecidos.

# %% [markdown]
# Respondemos a la pregunta 6:<br>
# 6- ¿La vivienda tiene más dormitorios si tengo mayor nivel educacional?<br>
#
# Pareciera que si, pero es bien constante

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x=datos['region'],y=datos['edad']) #x debe ser categórica e y continua
plt.title('Diagrama de caja de la variable Edad por region',y=1.01)
plt.xlabel('Región')
plt.show()

# %% [markdown]
# La distribución de edad es parecida en todas las regiones.
# La primera y segunda región tienen más gente joven proporcionalmente, tienen mediana más baja.

# %% [markdown]
# Repsondemos a la pregunta 7:<br>
# 7. ¿Que región tiene mayor Q3 de edad?<br>
#
# La Región de Ñuble

# %%
# Calcular los conteos de cada categoría
conteos = datos['s12'].value_counts()

# Crear el gráfico de torta
desfase = (0,0.075,0,0,0,0,0,0,0,0)
plt.figure(figsize=(4,4)) #plt. hace referencia a la librería matplotlib
plt.pie(conteos, labels=conteos.index, autopct='%0.1f%%',explode=desfase)

# Agregar un título al gráfico
plt.title('Distribución de la variable Previsión de Salud',y=1.1) #y=1.1 cambia la posición del título

# Mostrar el gráfico
plt.axis('equal')  # Para que el gráfico sea un círculo en lugar de una elipse
plt.show()

# %% [markdown]
# La mayoría tiene Fonasa B
# Hay más gente que no sabe que previsión tiene que la de FF.AA.

# %% [markdown]
# Repondemos pregunta 8:<br>
#
# 8. ¿Porcentaje de personas con Fonasa A? <br>
#
# El 24.3% de la población tiene Fonasa A

# %%
#Histograma usando matplotlin
plt.figure(figsize=(4,4))
plot = plt.hist(datos.o10, bins = 8,density=False,edgecolor = 'black') # bins corresponde al num de segmentos
plt.title('Histograma de la variable horas trabajo semana',y=1.01)
plt.ylabel('Conteo de valores por cada segmento')
plt.xlabel('Horas de Trabajo Semanales')
plt.show()

# %% [markdown]
# La gran mayoría de la gente trabaja cerca de 50 horas.
# La asimetría es positiva.

# %%
plt.figure(figsize=(20,20))
count_plot = sns.countplot(x = datos.region, hue = datos.s12)
plt.title('Gráfico de barras para la variable Previsión por Región',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('Región')
plt.show()

# %% [markdown]
# En la región Metropolitana hay mucha gente con Isapre, y en la segunda región también comparando con las demás previsiones.
# La fonasa A y B se pelean entre las más populares excepto entre las dos regiones mencionadas arriba.

# %% [markdown]
# Respondemos a la pregunta 10:<br>
# 10. ¿Cuál es la previsión más común en La Araucanía?<br>
#
# La mayoría está en Fonasa A
